# %% [markdown]
# <a href="https://colab.research.google.com/github/yeesem/Deep_Learning/blob/main/Introduce_to_Keras_Callbacks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import io
from PIL import Image

from tensorflow.keras.callbacks import TensorBoard, EarlyStopping,LearningRateScheduler, ModelCheckpoint, CSVLogger, ReduceLROnPlateau

import os
import matplotlib.pylab as plt
import numpy as np
import math
import datetime
import pandas as pd

# %%
# Download and prepare the horses or human dataset
path = './tensorflow_datasets'
splits, info = tfds.load('horses_or_humans', data_dir=path, as_supervised=True, with_info=True, split=['train[:80%]', 'train[80%:]', 'test'])

(train_examples,validation_examples,test_examples) = splits

num_examples = info.splits['train'].num_examples
num_classes = info.features['label'].num_classes
# Out:
# Downloading and preparing dataset 153.59 MiB (download: 153.59 MiB, generated: Unknown size, total: 153.59 MiB) to ./tensorflow_datasets/horses_or_humans/3.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/1027 [00:00<?, ? examples/s]
# Shuffling tensorflow_datasets/horses_or_humans/3.0.0.incompleteIANZ48/horses_or_humans-train.tfrecord*...:   0…
# Generating test examples...:   0%|          | 0/256 [00:00<?, ? examples/s]
# Shuffling tensorflow_datasets/horses_or_humans/3.0.0.incompleteIANZ48/horses_or_humans-test.tfrecord*...:   0%…
# Dataset horses_or_humans downloaded and prepared to ./tensorflow_datasets/horses_or_humans/3.0.0. Subsequent calls will reuse this data.

# %%
SIZE = 150
IMAGE_SIZE = (SIZE,SIZE)

# %%
def format_image(image,label):
  image = tf.image.resize(image,IMAGE_SIZE)/255.0
  return image,label

# %%
BATCH_SIZE = 32

# %%
train_batches = train_examples.shuffle(num_examples // 4).map(format_image).batch(BATCH_SIZE)
validation_batches = validation_examples.map(format_image).batch(BATCH_SIZE).prefetch(1)
test_batches = test_examples.map(format_image).batch(1)

# %%
for image_batch,label_batch in train_batches.take(1):
  pass

image_batch.shape
# Out:
# TensorShape([32, 150, 150, 3])

# %%
def build_model(dense_units , input_shape = IMAGE_SIZE + (3,)):
  model = tf.keras.models.Sequential([
      tf.keras.layers.Conv2D(16,(3,3),activation = "relu",input_shape = input_shape),
      tf.keras.layers.MaxPooling2D(2,2),
      tf.keras.layers.Conv2D(32,(3,3),activation = 'relu'),
      tf.keras.layers.MaxPooling2D(2,2),
      tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
      tf.keras.layers.MaxPooling2D(2,2),
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(dense_units,activation = 'relu'),
      tf.keras.layers.Dense(2,activation = 'softmax')
      ])
  return model

# %% [markdown]
# # TensorBoard

# %%
# !rm -rf logs

# %%
model = build_model(dense_units = 256)
model.compile(
    optimizer = 'sgd',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

logdir = os.path.join('logs',datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir)

model.fit(
    train_batches,
    epochs = 10,
    validation_data = validation_batches,
    callbacks = [tensorboard_callback]
)
# Out:
# Epoch 1/10
# 26/26 [==============================] - 25s 872ms/step - loss: 0.6767 - accuracy: 0.5633 - val_loss: 0.6655 - val_accuracy: 0.7220
# Epoch 2/10
# 26/26 [==============================] - 19s 742ms/step - loss: 0.6407 - accuracy: 0.7178 - val_loss: 0.6228 - val_accuracy: 0.7756
# Epoch 3/10
# 26/26 [==============================] - 21s 811ms/step - loss: 0.5811 - accuracy: 0.7664 - val_loss: 0.5405 - val_accuracy: 0.8049
# Epoch 4/10
# 26/26 [==============================] - 27s 1s/step - loss: 0.5176 - accuracy: 0.7737 - val_loss: 0.4969 - val_accuracy: 0.8098
# Epoch 5/10
# 26/26 [==============================] - 29s 1s/step - loss: 0.4480 - accuracy: 0.8066 - val_loss: 0.4034 - val_accuracy: 0.8341
# Epoch 6/10
# 26/26 [==============================] - 19s 746ms/step - loss: 0.3910 - accuracy: 0.8406 - val_loss: 0.3332 - val_accuracy: 0.8585
# Epoch 7/10
# 26/26 [==============================] - 18s 708ms/step - loss: 0.3599 - accuracy: 0.8443 - val_loss: 0.3401 - val_accuracy: 0.8829
# Epoch 8/10
# 26/26 [==============================] - 21s 803ms/step - loss: 0.2723 - accuracy: 0.9161 - val_loss: 0.2142 - val_accuracy: 0.9415
# Epoch 9/10
# 26/26 [==============================] - 23s 884ms/step - loss: 0.2265 - accuracy: 0.9282 - val_loss: 0.2744 - val_accuracy: 0.8780
# Epoch 10/10
# 26/26 [==============================] - 30s 1s/step - loss: 0.1921 - accuracy: 0.9440 - val_loss: 0.1340 - val_accuracy: 0.9659

# %% [markdown]
# # Model Checkpoint

# %%
model = build_model(dense_units = 256)
model.compile(
    optimizer = 'sgd',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

model.fit(
    train_batches,
    epochs = 5,
    validation_data = validation_batches,
    verbose = 2,
    callbacks = [
        ModelCheckpoint('weights.{epoch:02d}-{val_loss:.2f}.h5', verbose=1)
    ]
)
# Out:
# Epoch 1/5
#
# Epoch 1: saving model to weights.01-0.67.h5
# 26/26 - 30s - loss: 0.6722 - accuracy: 0.5985 - val_loss: 0.6733 - val_accuracy: 0.5122 - 30s/epoch - 1s/step
# Epoch 2/5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: saving model to weights.02-0.62.h5
# 26/26 - 21s - loss: 0.6418 - accuracy: 0.6837 - val_loss: 0.6225 - val_accuracy: 0.8098 - 21s/epoch - 811ms/step
# Epoch 3/5
#
# Epoch 3: saving model to weights.03-0.62.h5
# 26/26 - 27s - loss: 0.5965 - accuracy: 0.7360 - val_loss: 0.6161 - val_accuracy: 0.6049 - 27s/epoch - 1s/step
# Epoch 4/5
#
# Epoch 4: saving model to weights.04-0.52.h5
# 26/26 - 18s - loss: 0.5432 - accuracy: 0.7372 - val_loss: 0.5168 - val_accuracy: 0.8049 - 18s/epoch - 685ms/step
# Epoch 5/5
#
# Epoch 5: saving model to weights.05-0.44.h5
# 26/26 - 19s - loss: 0.4815 - accuracy: 0.7981 - val_loss: 0.4426 - val_accuracy: 0.7951 - 19s/epoch - 726ms/step

# %% [markdown]
# # Early Stopping

# %%
'''
min_delta: This parameter specifies the minimum change in the monitored metric
          to qualify as an improvement. If the change in the monitored metric is less
          than min_delta, it's not considered as an improvement. Early stopping will only
          trigger if the improvement is greater than min_delta. This helps prevent stopping
          training prematurely due to minor fluctuations in the metric.
baseline: This parameter sets the threshold value for the monitored metric. If the monitored
          metric doesn't improve by at least min_delta from the baseline value, early stopping is
          triggered. It's essentially the initial value from which improvements are measured. If
          the monitored metric doesn't exceed this baseline plus min_delta, training will stop.
'''

model = build_model(dense_units = 256)
model.compile(
    optimizer = 'sgd',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

model.fit(
    train_batches,
    epochs = 50,
    validation_data = validation_batches,
    verbose = 2,
    callbacks = [
        EarlyStopping(
            patience = 3,
            min_delta = 0.05,
            baseline = 0.8,
            mode = 'min',
            monitor = 'val_loss',
            restore_best_weights = True,
            verbose = 1
        )
    ]
)
# Out:
# Epoch 1/50
# 26/26 - 22s - loss: 0.6815 - accuracy: 0.5487 - val_loss: 0.6886 - val_accuracy: 0.4341 - 22s/epoch - 848ms/step
# Epoch 2/50
# 26/26 - 19s - loss: 0.6561 - accuracy: 0.6022 - val_loss: 0.6473 - val_accuracy: 0.6927 - 19s/epoch - 723ms/step
# Epoch 3/50
# 26/26 - 17s - loss: 0.6246 - accuracy: 0.7482 - val_loss: 0.6122 - val_accuracy: 0.7122 - 17s/epoch - 658ms/step
# Epoch 4/50
# 26/26 - 18s - loss: 0.5655 - accuracy: 0.7932 - val_loss: 0.5298 - val_accuracy: 0.8683 - 18s/epoch - 692ms/step
# Epoch 5/50
# 26/26 - 18s - loss: 0.4997 - accuracy: 0.8151 - val_loss: 0.4574 - val_accuracy: 0.8049 - 18s/epoch - 674ms/step
# Epoch 6/50
# 26/26 - 19s - loss: 0.4155 - accuracy: 0.8601 - val_loss: 0.3632 - val_accuracy: 0.9122 - 19s/epoch - 727ms/step
# Epoch 7/50
# 26/26 - 21s - loss: 0.3324 - accuracy: 0.8905 - val_loss: 0.2688 - val_accuracy: 0.9317 - 21s/epoch - 824ms/step
# Epoch 8/50
# 26/26 - 20s - loss: 0.2550 - accuracy: 0.9258 - val_loss: 0.3307 - val_accuracy: 0.8829 - 20s/epoch - 780ms/step
# Epoch 9/50
# 26/26 - 23s - loss: 0.2175 - accuracy: 0.9343 - val_loss: 0.2411 - val_accuracy: 0.9171 - 23s/epoch - 899ms/step
# Epoch 10/50
# 26/26 - 22s - loss: 0.1844 - accuracy: 0.9380 - val_loss: 0.1545 - val_accuracy: 0.9610 - 22s/epoch - 838ms/step
# Epoch 11/50
# 26/26 - 27s - loss: 0.1448 - accuracy: 0.9550 - val_loss: 0.1167 - val_accuracy: 0.9805 - 27s/epoch - 1s/step
# Epoch 12/50
# 26/26 - 20s - loss: 0.1358 - accuracy: 0.9623 - val_loss: 0.0992 - val_accuracy: 0.9854 - 20s/epoch - 751ms/step
# Epoch 13/50
# 26/26 - 21s - loss: 0.1067 - accuracy: 0.9684 - val_loss: 0.0891 - val_accuracy: 0.9854 - 21s/epoch - 823ms/step
# Epoch 14/50
# 26/26 - 27s - loss: 0.0977 - accuracy: 0.9745 - val_loss: 0.0804 - val_accuracy: 0.9902 - 27s/epoch - 1s/step
# Epoch 15/50
# Restoring model weights from the end of the best epoch: 12.
# 26/26 - 27s - loss: 0.0887 - accuracy: 0.9745 - val_loss: 0.0784 - val_accuracy: 0.9805 - 27s/epoch - 1s/step
# Epoch 15: early stopping

# %% [markdown]
# # CSV Logger

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

csv_file = 'training.csv'

model.fit(
    train_batches,
    epochs = 5,
    validation_data = validation_batches,
    callbacks = [
        CSVLogger(csv_file)
    ]
)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 30s 1s/step - loss: 0.6857 - accuracy: 0.5852 - val_loss: 0.6514 - val_accuracy: 0.6244
# Epoch 2/5
# 26/26 [==============================] - 20s 757ms/step - loss: 0.6288 - accuracy: 0.6533 - val_loss: 0.6178 - val_accuracy: 0.6488
# Epoch 3/5
# 26/26 [==============================] - 19s 744ms/step - loss: 0.5729 - accuracy: 0.6922 - val_loss: 0.5296 - val_accuracy: 0.7854
# Epoch 4/5
# 26/26 [==============================] - 19s 747ms/step - loss: 0.5316 - accuracy: 0.7518 - val_loss: 0.6036 - val_accuracy: 0.6195
# Epoch 5/5
# 26/26 [==============================] - 18s 690ms/step - loss: 0.4726 - accuracy: 0.8187 - val_loss: 0.4828 - val_accuracy: 0.7220

# %% [markdown]
# # Learning Rate Scheduler

# %%
'''
drop: This parameter specifies the factor by which the learning rate is reduced.
      After every epochs_drop epochs, the learning rate will be multiplied by this factor.
      For example, if drop is set to 0.5, it means the learning rate will be halved every
      epochs_drop epochs.

epochs_drop: This parameter determines how often (in terms of epochs) the learning rate
            will be updated. After every epochs_drop epochs, the learning rate will be adjusted
            according to the specified drop factor.
'''

model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

def step_decay(epoch):
  initial_lr = 0.01
  drop = 0.5
  epochs_drop = 1
  lr = initial_lr * math.pow(drop, math.floor((1+epoch)/epochs_drop))
  return lr

model.fit(train_batches,
          epochs=5,
          validation_data=validation_batches,
          callbacks=[LearningRateScheduler(step_decay, verbose=1),
                    TensorBoard(log_dir='./log_dir')])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.005.
# Epoch 1/5
# 26/26 [==============================] - 22s 830ms/step - loss: 0.6716 - accuracy: 0.5779 - val_loss: 0.6813 - val_accuracy: 0.4829 - lr: 0.0050
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 2/5
# 26/26 [==============================] - 22s 858ms/step - loss: 0.6326 - accuracy: 0.6667 - val_loss: 0.6362 - val_accuracy: 0.7268 - lr: 0.0025
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 3/5
# 26/26 [==============================] - 22s 872ms/step - loss: 0.6172 - accuracy: 0.7129 - val_loss: 0.6404 - val_accuracy: 0.6098 - lr: 0.0012
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 4/5
# 26/26 [==============================] - 18s 677ms/step - loss: 0.6080 - accuracy: 0.7226 - val_loss: 0.6267 - val_accuracy: 0.6976 - lr: 6.2500e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0003125.
# Epoch 5/5
# 26/26 [==============================] - 20s 763ms/step - loss: 0.6037 - accuracy: 0.7421 - val_loss: 0.6210 - val_accuracy: 0.7366 - lr: 3.1250e-04

# %% [markdown]
# # ReduceLROnPlateau
# Reduce learning rate when a metric has stopped improving.<br>
# Adjust the learning rate dynamically based on the validation loss.

# %%
'''
min_lr: This parameter specifies the minimum value that the learning rate can reach.
        If, during training, the learning rate falls below this value, it will not be further
        reduced. This helps prevent the learning rate from becoming too small, which could
        hinder convergence.

factor: This parameter determines the factor by which the learning rate will be reduced.
        If the validation loss plateaus (stops improving), the learning rate will be updated by
        multiplying it by this factor. For example, if factor is set to 0.2, it means that the
        learning rate will be reduced to 20% of its current value whenever the validation
        loss plateaus.
'''

model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

model.fit(train_batches,
          epochs=50,
          validation_data=validation_batches,
          callbacks=[ReduceLROnPlateau(monitor='val_loss',
                                       factor=0.2, verbose=1,
                                       patience=1, min_lr=0.001),
                     TensorBoard(log_dir='./log_dir')])
# Out:
# Epoch 1/50
# 26/26 [==============================] - 21s 794ms/step - loss: 0.6700 - accuracy: 0.6107 - val_loss: 0.6316 - val_accuracy: 0.8049 - lr: 0.0100
# Epoch 2/50
# 26/26 [==============================] - 21s 796ms/step - loss: 0.6203 - accuracy: 0.6703 - val_loss: 0.5902 - val_accuracy: 0.7805 - lr: 0.0100
# Epoch 3/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5625 - accuracy: 0.7360
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 26/26 [==============================] - 18s 711ms/step - loss: 0.5625 - accuracy: 0.7360 - val_loss: 0.7039 - val_accuracy: 0.4878 - lr: 0.0100
# Epoch 4/50
# 26/26 [==============================] - 18s 704ms/step - loss: 0.5137 - accuracy: 0.8066 - val_loss: 0.4972 - val_accuracy: 0.8976 - lr: 0.0020
# Epoch 5/50
# 26/26 [==============================] - 17s 655ms/step - loss: 0.4887 - accuracy: 0.8491 - val_loss: 0.4890 - val_accuracy: 0.8488 - lr: 0.0020
# Epoch 6/50
# 26/26 [==============================] - 20s 777ms/step - loss: 0.4701 - accuracy: 0.8358 - val_loss: 0.4554 - val_accuracy: 0.8976 - lr: 0.0020
# Epoch 7/50
# 26/26 [==============================] - 18s 714ms/step - loss: 0.4556 - accuracy: 0.8589 - val_loss: 0.4516 - val_accuracy: 0.8634 - lr: 0.0020
# Epoch 8/50
# 26/26 [==============================] - 17s 660ms/step - loss: 0.4332 - accuracy: 0.8577 - val_loss: 0.4336 - val_accuracy: 0.8634 - lr: 0.0020
# Epoch 9/50
# 26/26 [==============================] - 17s 673ms/step - loss: 0.4220 - accuracy: 0.8564 - val_loss: 0.4037 - val_accuracy: 0.8976 - lr: 0.0020
# Epoch 10/50
# 26/26 [==============================] - 18s 662ms/step - loss: 0.4097 - accuracy: 0.8552 - val_loss: 0.3811 - val_accuracy: 0.9073 - lr: 0.0020
# Epoch 11/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3886 - accuracy: 0.8698
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.001.
# 26/26 [==============================] - 17s 670ms/step - loss: 0.3886 - accuracy: 0.8698 - val_loss: 0.3843 - val_accuracy: 0.8732 - lr: 0.0020
# Epoch 12/50
# 26/26 [==============================] - 19s 734ms/step - loss: 0.3704 - accuracy: 0.8808 - val_loss: 0.3483 - val_accuracy: 0.9317 - lr: 0.0010
# Epoch 13/50
# 26/26 [==============================] - 17s 666ms/step - loss: 0.3637 - accuracy: 0.8844 - val_loss: 0.3371 - val_accuracy: 0.9415 - lr: 0.0010
# Epoch 14/50
# 26/26 [==============================] - 19s 723ms/step - loss: 0.3534 - accuracy: 0.8917 - val_loss: 0.3317 - val_accuracy: 0.9366 - lr: 0.0010
# Epoch 15/50
# 26/26 [==============================] - 19s 724ms/step - loss: 0.3464 - accuracy: 0.8905 - val_loss: 0.3198 - val_accuracy: 0.9415 - lr: 0.0010
# Epoch 16/50
# 26/26 [==============================] - 18s 706ms/step - loss: 0.3387 - accuracy: 0.8893 - val_loss: 0.3345 - val_accuracy: 0.8976 - lr: 0.0010
# Epoch 17/50
# 26/26 [==============================] - 17s 665ms/step - loss: 0.3314 - accuracy: 0.8966 - val_loss: 0.3093 - val_accuracy: 0.9415 - lr: 0.0010
# Epoch 18/50
# 26/26 [==============================] - 19s 712ms/step - loss: 0.3250 - accuracy: 0.8929 - val_loss: 0.3234 - val_accuracy: 0.9024 - lr: 0.0010
# Epoch 19/50
# 26/26 [==============================] - 17s 668ms/step - loss: 0.3174 - accuracy: 0.8942 - val_loss: 0.3198 - val_accuracy: 0.9024 - lr: 0.0010
# Epoch 20/50
# 26/26 [==============================] - 17s 668ms/step - loss: 0.3106 - accuracy: 0.9051 - val_loss: 0.2918 - val_accuracy: 0.9366 - lr: 0.0010
# Epoch 21/50
# 26/26 [==============================] - 17s 657ms/step - loss: 0.3016 - accuracy: 0.9136 - val_loss: 0.2731 - val_accuracy: 0.9415 - lr: 0.0010
# Epoch 22/50
# 26/26 [==============================] - 20s 763ms/step - loss: 0.2955 - accuracy: 0.9063 - val_loss: 0.2662 - val_accuracy: 0.9415 - lr: 0.0010
# Epoch 23/50
# 26/26 [==============================] - 17s 669ms/step - loss: 0.2884 - accuracy: 0.9148 - val_loss: 0.2889 - val_accuracy: 0.9220 - lr: 0.0010
# Epoch 24/50
# 26/26 [==============================] - 20s 768ms/step - loss: 0.2798 - accuracy: 0.9185 - val_loss: 0.2635 - val_accuracy: 0.9366 - lr: 0.0010
# Epoch 25/50
# 26/26 [==============================] - 17s 664ms/step - loss: 0.2734 - accuracy: 0.9221 - val_loss: 0.2525 - val_accuracy: 0.9366 - lr: 0.0010
# Epoch 26/50
# 26/26 [==============================] - 18s 705ms/step - loss: 0.2653 - accuracy: 0.9221 - val_loss: 0.2446 - val_accuracy: 0.9366 - lr: 0.0010
# Epoch 27/50
# 26/26 [==============================] - 17s 659ms/step - loss: 0.2595 - accuracy: 0.9294 - val_loss: 0.2372 - val_accuracy: 0.9463 - lr: 0.0010
# Epoch 28/50
# 26/26 [==============================] - 19s 703ms/step - loss: 0.2531 - accuracy: 0.9294 - val_loss: 0.2715 - val_accuracy: 0.9268 - lr: 0.0010
# Epoch 29/50
# 26/26 [==============================] - 17s 659ms/step - loss: 0.2482 - accuracy: 0.9294 - val_loss: 0.2229 - val_accuracy: 0.9463 - lr: 0.0010
# Epoch 30/50
# 26/26 [==============================] - 17s 657ms/step - loss: 0.2407 - accuracy: 0.9331 - val_loss: 0.2472 - val_accuracy: 0.9268 - lr: 0.0010
# Epoch 31/50
# 26/26 [==============================] - 18s 697ms/step - loss: 0.2319 - accuracy: 0.9465 - val_loss: 0.2594 - val_accuracy: 0.9220 - lr: 0.0010
# Epoch 32/50
# 26/26 [==============================] - 20s 760ms/step - loss: 0.2262 - accuracy: 0.9380 - val_loss: 0.2066 - val_accuracy: 0.9512 - lr: 0.0010
# Epoch 33/50
# 26/26 [==============================] - 18s 697ms/step - loss: 0.2263 - accuracy: 0.9367 - val_loss: 0.2032 - val_accuracy: 0.9512 - lr: 0.0010
# Epoch 34/50
# 26/26 [==============================] - 17s 668ms/step - loss: 0.2189 - accuracy: 0.9404 - val_loss: 0.1940 - val_accuracy: 0.9561 - lr: 0.0010
# Epoch 35/50
# 26/26 [==============================] - 18s 712ms/step - loss: 0.2107 - accuracy: 0.9392 - val_loss: 0.2180 - val_accuracy: 0.9317 - lr: 0.0010
# Epoch 36/50
# 26/26 [==============================] - 18s 677ms/step - loss: 0.2045 - accuracy: 0.9526 - val_loss: 0.1878 - val_accuracy: 0.9561 - lr: 0.0010
# Epoch 37/50
# 26/26 [==============================] - 17s 667ms/step - loss: 0.1974 - accuracy: 0.9428 - val_loss: 0.1794 - val_accuracy: 0.9561 - lr: 0.0010
# Epoch 38/50
# 26/26 [==============================] - 17s 655ms/step - loss: 0.1909 - accuracy: 0.9562 - val_loss: 0.1868 - val_accuracy: 0.9366 - lr: 0.0010
# Epoch 39/50
# 26/26 [==============================] - 17s 668ms/step - loss: 0.1890 - accuracy: 0.9574 - val_loss: 0.1745 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 40/50
# 26/26 [==============================] - 18s 702ms/step - loss: 0.1819 - accuracy: 0.9538 - val_loss: 0.1693 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 41/50
# 26/26 [==============================] - 17s 664ms/step - loss: 0.1818 - accuracy: 0.9635 - val_loss: 0.1670 - val_accuracy: 0.9561 - lr: 0.0010
# Epoch 42/50
# 26/26 [==============================] - 19s 717ms/step - loss: 0.1710 - accuracy: 0.9647 - val_loss: 0.1595 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 43/50
# 26/26 [==============================] - 19s 721ms/step - loss: 0.1716 - accuracy: 0.9684 - val_loss: 0.1887 - val_accuracy: 0.9366 - lr: 0.0010
# Epoch 44/50
# 26/26 [==============================] - 17s 657ms/step - loss: 0.1612 - accuracy: 0.9708 - val_loss: 0.1889 - val_accuracy: 0.9366 - lr: 0.0010
# Epoch 45/50
# 26/26 [==============================] - 18s 705ms/step - loss: 0.1588 - accuracy: 0.9708 - val_loss: 0.1514 - val_accuracy: 0.9659 - lr: 0.0010
# Epoch 46/50
# 26/26 [==============================] - 17s 664ms/step - loss: 0.1544 - accuracy: 0.9672 - val_loss: 0.1679 - val_accuracy: 0.9415 - lr: 0.0010
# Epoch 47/50
# 26/26 [==============================] - 17s 672ms/step - loss: 0.1497 - accuracy: 0.9745 - val_loss: 0.1573 - val_accuracy: 0.9366 - lr: 0.0010
# Epoch 48/50
# 26/26 [==============================] - 19s 751ms/step - loss: 0.1465 - accuracy: 0.9659 - val_loss: 0.1554 - val_accuracy: 0.9366 - lr: 0.0010
# Epoch 49/50
# 26/26 [==============================] - 19s 723ms/step - loss: 0.1425 - accuracy: 0.9745 - val_loss: 0.1405 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 50/50
# 26/26 [==============================] - 18s 698ms/step - loss: 0.1375 - accuracy: 0.9781 - val_loss: 0.1344 - val_accuracy: 0.9707 - lr: 0.0010
